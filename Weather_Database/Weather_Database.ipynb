# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
#set of random latitude and longitude combinations
#lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
#lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
#lat_lngs =zip(lats, lngs)
#lat_lngs
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | bahia blanca
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | nesna
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | uige
# Processing Record 10 of Set 1 | kumluca
# Processing Record 11 of Set 1 | bossangoa
# Processing Record 12 of Set 1 | guerrero negro
# Processing Record 13 of Set 1 | fort nelson
# Processing Record 14 of Set 1 | sindor
# Processing Record 15 of Set 1 | lander
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | robe
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | rumphi
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | benicarlo
# Processing Record 22 of Set 1 | okoneshnikovo
# Processing Record 23 of Set 1 | margate
# Processing Record 24 of Set 1 | tasiilaq
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | champerico
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | luchegorsk
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | elizabeth city
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | kodinsk
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | kerema
# Processing Record 40 of Set 1 | walvis bay
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | maniitsoq
# Processing Record 44 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 1 | klaksvik
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 1 | kharp
# Processing Record 50 of Set 1 | palaikastron
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | manta
# Processing Record 3 of Set 2 | chuy
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | pinheiro machado
# Processing Record 6 of Set 2 | ananas
# Processing Record 7 of Set 2 | nanortalik
# Processing Record 8 of Set 2 | puerto penasco
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | porto novo
# Processing Record 11 of Set 2 | taft
# Processing Record 12 of Set 2 | hoorn
# Processing Record 13 of Set 2 | charyshskoye
# Processing Record 14 of Set 2 | necochea
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | kuusamo
# Processing Record 17 of Set 2 | iwanai
# Processing Record 18 of Set 2 | vanavara
# Processing Record 19 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | kazachinskoye
# Processing Record 23 of Set 2 | kovilpatti
# Processing Record 24 of Set 2 | constitucion
# Processing Record 25 of Set 2 | karratha
# Processing Record 26 of Set 2 | faanui
# Processing Record 27 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | tianjin
# Processing Record 30 of Set 2 | ambunti
# Processing Record 31 of Set 2 | dingle
# Processing Record 32 of Set 2 | norman wells
# Processing Record 33 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 2 | ushuaia
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | brae
# Processing Record 39 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 2 | padang
# Processing Record 41 of Set 2 | longyearbyen
# Processing Record 42 of Set 2 | quatre cocos
# Processing Record 43 of Set 2 | fairbanks
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | saint-georges
# Processing Record 46 of Set 2 | eufaula
# Processing Record 47 of Set 2 | fortuna
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | oil city
# Processing Record 50 of Set 2 | santa cruz
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | khandyga
# Processing Record 3 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 3 | arlit
# Processing Record 5 of Set 3 | lata
# Processing Record 6 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 3 | naze
# Processing Record 8 of Set 3 | tucupita
# Processing Record 9 of Set 3 | coahuayana
# Processing Record 10 of Set 3 | tilichiki
# Processing Record 11 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | ballina
# Processing Record 14 of Set 3 | kerouane
# Processing Record 15 of Set 3 | richards bay
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | mahebourg
# Processing Record 19 of Set 3 | kavieng
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | bluff
# Processing Record 22 of Set 3 | narang
# Processing Record 23 of Set 3 | ajaccio
# Processing Record 24 of Set 3 | saldanha
# Processing Record 25 of Set 3 | ban nahin
# Processing Record 26 of Set 3 | xichang
# Processing Record 27 of Set 3 | sao filipe
# Processing Record 28 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 3 | olafsvik
# Processing Record 30 of Set 3 | puri
# Processing Record 31 of Set 3 | kingsville
# Processing Record 32 of Set 3 | mar del plata
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | tiksi
# Processing Record 35 of Set 3 | cape town
# Processing Record 36 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 3 | komsomolskiy
# Processing Record 38 of Set 3 | vao
# Processing Record 39 of Set 3 | samarai
# Processing Record 40 of Set 3 | mataura
# Processing Record 41 of Set 3 | kristiinankaupunki
# Processing Record 42 of Set 3 | tandil
# Processing Record 43 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 3 | avera
# Processing Record 45 of Set 3 | yulara
# Processing Record 46 of Set 3 | huddersfield
# Processing Record 47 of Set 3 | zeya
# Processing Record 48 of Set 3 | narsaq
# Processing Record 49 of Set 3 | merauke
# Processing Record 50 of Set 3 | lagoa
# Processing Record 1 of Set 4 | tahta
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | mayo
# Processing Record 4 of Set 4 | gojo
# Processing Record 5 of Set 4 | xuddur
# Processing Record 6 of Set 4 | talnakh
# Processing Record 7 of Set 4 | bubaque
# Processing Record 8 of Set 4 | bani
# Processing Record 9 of Set 4 | kvarkeno
# Processing Record 10 of Set 4 | aix-en-provence
# Processing Record 11 of Set 4 | pitimbu
# Processing Record 12 of Set 4 | lahij
# Processing Record 13 of Set 4 | salalah
# Processing Record 14 of Set 4 | barrhead
# Processing Record 15 of Set 4 | mount gambier
# Processing Record 16 of Set 4 | boa vista
# Processing Record 17 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 4 | yellowknife
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | aldan
# Processing Record 21 of Set 4 | kuching
# Processing Record 22 of Set 4 | turukhansk
# Processing Record 23 of Set 4 | bandarbeyla
# Processing Record 24 of Set 4 | ribeira grande
# Processing Record 25 of Set 4 | kishi
# Processing Record 26 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 4 | maragogi
# Processing Record 28 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | hambantota
# Processing Record 31 of Set 4 | college
# Processing Record 32 of Set 4 | bambous virieux
# Processing Record 33 of Set 4 | rocha
# Processing Record 34 of Set 4 | tuatapere
# Processing Record 35 of Set 4 | vila franca do campo
# Processing Record 36 of Set 4 | udachnyy
# Processing Record 37 of Set 4 | vila velha
# Processing Record 38 of Set 4 | taoudenni
# Processing Record 39 of Set 4 | rocky mountain house
# Processing Record 40 of Set 4 | ilulissat
# Processing Record 41 of Set 4 | namatanai
# Processing Record 42 of Set 4 | vershino-darasunskiy
# Processing Record 43 of Set 4 | maldonado
# Processing Record 44 of Set 4 | leominster
# Processing Record 45 of Set 4 | avarua
# Processing Record 46 of Set 4 | luanda
# Processing Record 47 of Set 4 | yurya
# City not found. Skipping...
# Processing Record 48 of Set 4 | tambopata
# Processing Record 49 of Set 4 | kapoeta
# Processing Record 50 of Set 4 | odweyne
# Processing Record 1 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 5 | pokhara
# Processing Record 3 of Set 5 | eureka
# Processing Record 4 of Set 5 | vangaindrano
# Processing Record 5 of Set 5 | mahibadhoo
# Processing Record 6 of Set 5 | port hardy
# Processing Record 7 of Set 5 | beringovskiy
# Processing Record 8 of Set 5 | yarkovo
# Processing Record 9 of Set 5 | provideniya
# Processing Record 10 of Set 5 | quelimane
# Processing Record 11 of Set 5 | bilma
# Processing Record 12 of Set 5 | goundam
# Processing Record 13 of Set 5 | katete
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | sivaki
# Processing Record 16 of Set 5 | paamiut
# Processing Record 17 of Set 5 | sabha
# Processing Record 18 of Set 5 | kruisfontein
# Processing Record 19 of Set 5 | kodiak
# Processing Record 20 of Set 5 | baculin
# Processing Record 21 of Set 5 | malakal
# Processing Record 22 of Set 5 | tommot
# Processing Record 23 of Set 5 | meulaboh
# Processing Record 24 of Set 5 | ye
# City not found. Skipping...
# Processing Record 25 of Set 5 | escarcega
# Processing Record 26 of Set 5 | cochabamba
# Processing Record 27 of Set 5 | mecca
# Processing Record 28 of Set 5 | bodden town
# Processing Record 29 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 5 | san patricio
# Processing Record 31 of Set 5 | alta floresta
# Processing Record 32 of Set 5 | los llanos de aridane
# Processing Record 33 of Set 5 | barentu
# Processing Record 34 of Set 5 | lardos
# Processing Record 35 of Set 5 | severo-kurilsk
# Processing Record 36 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 5 | stryn
# Processing Record 38 of Set 5 | jiuquan
# Processing Record 39 of Set 5 | saint-francois
# Processing Record 40 of Set 5 | touros
# Processing Record 41 of Set 5 | dharchula
# Processing Record 42 of Set 5 | konstantinovo
# Processing Record 43 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 5 | boende
# Processing Record 45 of Set 5 | qasigiannguit
# Processing Record 46 of Set 5 | east london
# Processing Record 47 of Set 5 | san quintin
# Processing Record 48 of Set 5 | camacha
# Processing Record 49 of Set 5 | black river
# Processing Record 50 of Set 5 | nelson bay
# Processing Record 1 of Set 6 | jalu
# Processing Record 2 of Set 6 | sheboygan
# Processing Record 3 of Set 6 | bethel
# Processing Record 4 of Set 6 | santa isabel do rio negro
# Processing Record 5 of Set 6 | jobabo
# Processing Record 6 of Set 6 | eucaliptus
# Processing Record 7 of Set 6 | khvastovichi
# Processing Record 8 of Set 6 | prescott
# Processing Record 9 of Set 6 | ahuimanu
# Processing Record 10 of Set 6 | san jose
# Processing Record 11 of Set 6 | half moon bay
# Processing Record 12 of Set 6 | cabo san lucas
# Processing Record 13 of Set 6 | borca
# Processing Record 14 of Set 6 | ortigueira
# Processing Record 15 of Set 6 | batemans bay
# Processing Record 16 of Set 6 | mabai
# Processing Record 17 of Set 6 | cam ranh
# Processing Record 18 of Set 6 | ayagoz
# Processing Record 19 of Set 6 | vanderhoof
# Processing Record 20 of Set 6 | namibe
# Processing Record 21 of Set 6 | at-bashi
# Processing Record 22 of Set 6 | gunjur
# Processing Record 23 of Set 6 | wonthaggi
# Processing Record 24 of Set 6 | haian
# Processing Record 25 of Set 6 | turbat
# Processing Record 26 of Set 6 | kieta
# Processing Record 27 of Set 6 | rognan
# Processing Record 28 of Set 6 | zhigansk
# Processing Record 29 of Set 6 | nago
# Processing Record 30 of Set 6 | alice springs
# Processing Record 31 of Set 6 | ust-kan
# Processing Record 32 of Set 6 | ha giang
# Processing Record 33 of Set 6 | saint-raymond
# Processing Record 34 of Set 6 | ardino
# Processing Record 35 of Set 6 | cortland
# Processing Record 36 of Set 6 | pevek
# Processing Record 37 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 6 | ixtapa
# Processing Record 39 of Set 6 | vanimo
# Processing Record 40 of Set 6 | marsabit
# Processing Record 41 of Set 6 | kargil
# Processing Record 42 of Set 6 | tello
# Processing Record 43 of Set 6 | castro
# Processing Record 44 of Set 6 | tucuma
# Processing Record 45 of Set 6 | hamilton
# Processing Record 46 of Set 6 | tonantins
# Processing Record 47 of Set 6 | jharia
# Processing Record 48 of Set 6 | roald
# Processing Record 49 of Set 6 | hauterive
# Processing Record 50 of Set 6 | smithers
# Processing Record 1 of Set 7 | williams lake
# Processing Record 2 of Set 7 | pisco
# Processing Record 3 of Set 7 | coquimbo
# Processing Record 4 of Set 7 | iguape
# Processing Record 5 of Set 7 | acarau
# Processing Record 6 of Set 7 | ponta delgada
# Processing Record 7 of Set 7 | cayenne
# Processing Record 8 of Set 7 | idar
# Processing Record 9 of Set 7 | kraskino
# Processing Record 10 of Set 7 | leh
# Processing Record 11 of Set 7 | amet
# Processing Record 12 of Set 7 | kyra
# Processing Record 13 of Set 7 | kahului
# Processing Record 14 of Set 7 | divnomorskoye
# Processing Record 15 of Set 7 | tandalti
# Processing Record 16 of Set 7 | novikovo
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | hualmay
# Processing Record 21 of Set 7 | mogadishu
# Processing Record 22 of Set 7 | maceio
# Processing Record 23 of Set 7 | les herbiers
# Processing Record 24 of Set 7 | marawi
# Processing Record 25 of Set 7 | svetlyy
# Processing Record 26 of Set 7 | poum
# Processing Record 27 of Set 7 | faya
# Processing Record 28 of Set 7 | iqaluit
# Processing Record 29 of Set 7 | rzhev
# Processing Record 30 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 31 of Set 7 | mandera
# Processing Record 32 of Set 7 | tehachapi
# Processing Record 33 of Set 7 | geraldton
# Processing Record 34 of Set 7 | jishui
# Processing Record 35 of Set 7 | lavrentiya
# Processing Record 36 of Set 7 | qena
# Processing Record 37 of Set 7 | carndonagh
# Processing Record 38 of Set 7 | prince rupert
# Processing Record 39 of Set 7 | khunti
# Processing Record 40 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 7 | amapa
# Processing Record 42 of Set 7 | gold coast
# Processing Record 43 of Set 7 | constantine
# Processing Record 44 of Set 7 | maumere
# Processing Record 45 of Set 7 | tenno
# Processing Record 46 of Set 7 | vondrozo
# Processing Record 47 of Set 7 | kon tum
# Processing Record 48 of Set 7 | harlingen
# Processing Record 49 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 7 | rudbar
# Processing Record 1 of Set 8 | hasaki
# Processing Record 2 of Set 8 | neuquen
# Processing Record 3 of Set 8 | victoria
# Processing Record 4 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 8 | balaka
# Processing Record 6 of Set 8 | ozernovskiy
# Processing Record 7 of Set 8 | hithadhoo
# Processing Record 8 of Set 8 | fortuna foothills
# Processing Record 9 of Set 8 | borzna
# Processing Record 10 of Set 8 | salta
# Processing Record 11 of Set 8 | najran
# Processing Record 12 of Set 8 | kirakira
# Processing Record 13 of Set 8 | lompoc
# Processing Record 14 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 15 of Set 8 | pangnirtung
# Processing Record 16 of Set 8 | gordeyevka
# Processing Record 17 of Set 8 | flinders
# Processing Record 18 of Set 8 | governador valadares
# Processing Record 19 of Set 8 | boyabat
# Processing Record 20 of Set 8 | breclav
# Processing Record 21 of Set 8 | yefira
# City not found. Skipping...
# Processing Record 22 of Set 8 | wanaka
# Processing Record 23 of Set 8 | kapit
# Processing Record 24 of Set 8 | moletai
# Processing Record 25 of Set 8 | christchurch
# Processing Record 26 of Set 8 | ocampo
# Processing Record 27 of Set 8 | abu dhabi
# Processing Record 28 of Set 8 | nemuro
# Processing Record 29 of Set 8 | letka
# Processing Record 30 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 8 | vestmannaeyjar
# Processing Record 32 of Set 8 | tsiroanomandidy
# Processing Record 33 of Set 8 | minsk
# Processing Record 34 of Set 8 | amalapuram
# Processing Record 35 of Set 8 | aripuana
# Processing Record 36 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 8 | mana
# Processing Record 38 of Set 8 | bukachacha
# Processing Record 39 of Set 8 | lithgow
# Processing Record 40 of Set 8 | poquoson
# Processing Record 41 of Set 8 | albina
# Processing Record 42 of Set 8 | chapais
# Processing Record 43 of Set 8 | manggar
# Processing Record 44 of Set 8 | marbella
# Processing Record 45 of Set 8 | grants
# Processing Record 46 of Set 8 | adrar
# Processing Record 47 of Set 8 | mackay
# Processing Record 48 of Set 8 | shamary
# Processing Record 49 of Set 8 | north platte
# Processing Record 50 of Set 8 | cherskiy
# Processing Record 1 of Set 9 | gilgit
# Processing Record 2 of Set 9 | broome
# Processing Record 3 of Set 9 | san jose de buan
# Processing Record 4 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 5 of Set 9 | pacifica
# Processing Record 6 of Set 9 | cradock
# Processing Record 7 of Set 9 | granadilla de abona
# Processing Record 8 of Set 9 | ostrovnoy
# Processing Record 9 of Set 9 | andros town
# Processing Record 10 of Set 9 | bilibino
# Processing Record 11 of Set 9 | farah
# Processing Record 12 of Set 9 | mwinilunga
# Processing Record 13 of Set 9 | kutum
# Processing Record 14 of Set 9 | mataram
# Processing Record 15 of Set 9 | itoman
# Processing Record 16 of Set 9 | leningradskiy
# Processing Record 17 of Set 9 | raahe
# Processing Record 18 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 9 | muros
# Processing Record 20 of Set 9 | tura
# Processing Record 21 of Set 9 | bairiki
# Processing Record 22 of Set 9 | linxia
# Processing Record 23 of Set 9 | muroto
# Processing Record 24 of Set 9 | columbus
# Processing Record 25 of Set 9 | thunder bay
# Processing Record 26 of Set 9 | sao joao da barra
# Processing Record 27 of Set 9 | unye
# City not found. Skipping...
# Processing Record 28 of Set 9 | gat
# Processing Record 29 of Set 9 | viransehir
# Processing Record 30 of Set 9 | trabzon
# Processing Record 31 of Set 9 | ribas do rio pardo
# Processing Record 32 of Set 9 | aklavik
# Processing Record 33 of Set 9 | beatrice
# Processing Record 34 of Set 9 | petrovskoye
# Processing Record 35 of Set 9 | reconquista
# Processing Record 36 of Set 9 | palmer
# Processing Record 37 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 9 | ahipara
# Processing Record 39 of Set 9 | tete
# Processing Record 40 of Set 9 | khor
# Processing Record 41 of Set 9 | oktyabrskoye
# Processing Record 42 of Set 9 | mariental
# Processing Record 43 of Set 9 | talcahuano
# Processing Record 44 of Set 9 | altay
# Processing Record 45 of Set 9 | mangaldai
# Processing Record 46 of Set 9 | marrakesh
# Processing Record 47 of Set 9 | mizdah
# Processing Record 48 of Set 9 | jinchang
# Processing Record 49 of Set 9 | buarcos
# Processing Record 50 of Set 9 | betioky
# Processing Record 1 of Set 10 | whitehorse
# Processing Record 2 of Set 10 | brigantine
# Processing Record 3 of Set 10 | qabis
# City not found. Skipping...
# Processing Record 4 of Set 10 | alofi
# Processing Record 5 of Set 10 | vung tau
# Processing Record 6 of Set 10 | kiunga
# Processing Record 7 of Set 10 | bowen
# Processing Record 8 of Set 10 | vilhena
# Processing Record 9 of Set 10 | valle de allende
# Processing Record 10 of Set 10 | kamenka
# Processing Record 11 of Set 10 | edd
# Processing Record 12 of Set 10 | liniere
# City not found. Skipping...
# Processing Record 13 of Set 10 | acajutla
# Processing Record 14 of Set 10 | kaeo
# Processing Record 15 of Set 10 | liseleje
# Processing Record 16 of Set 10 | saint-pierre
# Processing Record 17 of Set 10 | mugur-aksy
# Processing Record 18 of Set 10 | port blair
# Processing Record 19 of Set 10 | marzuq
# Processing Record 20 of Set 10 | celestun
# Processing Record 21 of Set 10 | gushikawa
# Processing Record 22 of Set 10 | hami
# Processing Record 23 of Set 10 | krasnokamensk
# Processing Record 24 of Set 10 | sisimiut
# Processing Record 25 of Set 10 | nome
# Processing Record 26 of Set 10 | nanakuli
# Processing Record 27 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 10 | omboue
# Processing Record 29 of Set 10 | virginia beach
# Processing Record 30 of Set 10 | clarence town
# Processing Record 31 of Set 10 | dabola
# Processing Record 32 of Set 10 | grand gaube
# Processing Record 33 of Set 10 | quesnel
# Processing Record 34 of Set 10 | sao sebastiao
# Processing Record 35 of Set 10 | peruibe
# Processing Record 36 of Set 10 | qui nhon
# Processing Record 37 of Set 10 | isangel
# Processing Record 38 of Set 10 | marsa matruh
# Processing Record 39 of Set 10 | nizhneangarsk
# Processing Record 40 of Set 10 | hay river
# Processing Record 41 of Set 10 | merrill
# Processing Record 42 of Set 10 | acuna
# City not found. Skipping...
# Processing Record 43 of Set 10 | fuerte olimpo
# Processing Record 44 of Set 10 | magrath
# Processing Record 45 of Set 10 | khani
# Processing Record 46 of Set 10 | namtsy
# Processing Record 47 of Set 10 | methven
# Processing Record 48 of Set 10 | clovis
# Processing Record 49 of Set 10 | baie-comeau
# Processing Record 50 of Set 10 | nouakchott
# Processing Record 1 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 2 of Set 11 | kalmunai
# Processing Record 3 of Set 11 | mahon
# Processing Record 4 of Set 11 | riyadh
# Processing Record 5 of Set 11 | conde
# Processing Record 6 of Set 11 | moindou
# Processing Record 7 of Set 11 | mehamn
# Processing Record 8 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 11 | viking
# Processing Record 10 of Set 11 | imbituva
# Processing Record 11 of Set 11 | moerai
# Processing Record 12 of Set 11 | maiquetia
# Processing Record 13 of Set 11 | bandrele
# Processing Record 14 of Set 11 | belmonte
# Processing Record 15 of Set 11 | grindavik
# Processing Record 16 of Set 11 | port lincoln
# Processing Record 17 of Set 11 | clyde river
# Processing Record 18 of Set 11 | beipiao
# Processing Record 19 of Set 11 | bengkulu
# Processing Record 20 of Set 11 | podyuga
# Processing Record 21 of Set 11 | kargasok
# Processing Record 22 of Set 11 | kloulklubed
# Processing Record 23 of Set 11 | mamakan
# Processing Record 24 of Set 11 | plettenberg bay
# Processing Record 25 of Set 11 | povenets
# Processing Record 26 of Set 11 | aksarka
# Processing Record 27 of Set 11 | angoram
# Processing Record 28 of Set 11 | rawson
# Processing Record 29 of Set 11 | dubbo
# Processing Record 30 of Set 11 | yumen
# Processing Record 31 of Set 11 | edgewater
# Processing Record 32 of Set 11 | rincon
# Processing Record 33 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 34 of Set 11 | saint george
# Processing Record 35 of Set 11 | gunnedah
# Processing Record 36 of Set 11 | haines junction
# Processing Record 37 of Set 11 | dongsheng
# Processing Record 38 of Set 11 | atambua
# Processing Record 39 of Set 11 | kigoma
# Processing Record 40 of Set 11 | veraval
# Processing Record 41 of Set 11 | krasnoselkup
# Processing Record 42 of Set 11 | el sauzal
# Processing Record 43 of Set 11 | klamath falls
# Processing Record 44 of Set 11 | gazanjyk
# Processing Record 45 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 11 | monrovia
# Processing Record 47 of Set 11 | deputatskiy
# Processing Record 48 of Set 11 | komsomolskoye
# Processing Record 49 of Set 11 | allende
# Processing Record 50 of Set 11 | neon karlovasion
# Processing Record 1 of Set 12 | hilton head island
# Processing Record 2 of Set 12 | palu
# Processing Record 3 of Set 12 | sawakin
# Processing Record 4 of Set 12 | northam
# Processing Record 5 of Set 12 | sault sainte marie
# Processing Record 6 of Set 12 | panaba
# Processing Record 7 of Set 12 | hokitika
# Processing Record 8 of Set 12 | vestbygda
# City not found. Skipping...
# Processing Record 9 of Set 12 | sorland
# Processing Record 10 of Set 12 | coihaique
# Processing Record 11 of Set 12 | mishkino
# Processing Record 12 of Set 12 | honiara
# Processing Record 13 of Set 12 | kathu
# Processing Record 14 of Set 12 | ukiah
# Processing Record 15 of Set 12 | the pas
# Processing Record 16 of Set 12 | abriaqui
# Processing Record 17 of Set 12 | canico
# Processing Record 18 of Set 12 | boissevain
# Processing Record 19 of Set 12 | mercedes
# Processing Record 20 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 21 of Set 12 | ushumun
# Processing Record 22 of Set 12 | tessalit
# Processing Record 23 of Set 12 | portland
# Processing Record 24 of Set 12 | barra do garcas
# Processing Record 25 of Set 12 | hopatcong
# Processing Record 26 of Set 12 | arti
# Processing Record 27 of Set 12 | san rafael
# Processing Record 28 of Set 12 | dawson
# Processing Record 29 of Set 12 | pachino
# Processing Record 30 of Set 12 | libertyville
# Processing Record 31 of Set 12 | puerto montt
# Processing Record 32 of Set 12 | pangai
# Processing Record 33 of Set 12 | lahti
# Processing Record 34 of Set 12 | changying
# Processing Record 35 of Set 12 | yar-sale
# Processing Record 36 of Set 12 | huarmey
# Processing Record 37 of Set 12 | sioux lookout
# Processing Record 38 of Set 12 | praia
# Processing Record 39 of Set 12 | pio xii
# Processing Record 40 of Set 12 | plouzane
# Processing Record 41 of Set 12 | invercargill
# Processing Record 42 of Set 12 | hays
# Processing Record 43 of Set 12 | haveli
# Processing Record 44 of Set 12 | japura
# Processing Record 45 of Set 12 | jumla
# Processing Record 46 of Set 12 | concordia
# Processing Record 47 of Set 12 | anchorage
# Processing Record 48 of Set 12 | bela vista
# Processing Record 49 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 12 | mezen
# Processing Record 1 of Set 13 | srednekolymsk
# Processing Record 2 of Set 13 | bethanien
# Processing Record 3 of Set 13 | gidole
# Processing Record 4 of Set 13 | saurimo
# Processing Record 5 of Set 13 | anadyr
# Processing Record 6 of Set 13 | kostyantynivka
# Processing Record 7 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 13 | saint paul
# Processing Record 9 of Set 13 | naryan-mar
# Processing Record 10 of Set 13 | north battleford
# Processing Record 11 of Set 13 | joshimath
# Processing Record 12 of Set 13 | dudinka
# Processing Record 13 of Set 13 | ust-tsilma
# Processing Record 14 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 15 of Set 13 | camara de lobos
# Processing Record 16 of Set 13 | orchard homes
# Processing Record 17 of Set 13 | zelezniki
# Processing Record 18 of Set 13 | laguna
# Processing Record 19 of Set 13 | taltal
# Processing Record 20 of Set 13 | azad shahr
# Processing Record 21 of Set 13 | suslovo
# Processing Record 22 of Set 13 | riyaq
# City not found. Skipping...
# Processing Record 23 of Set 13 | saint-louis
# Processing Record 24 of Set 13 | emerald
# Processing Record 25 of Set 13 | mafeteng
# Processing Record 26 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 13 | shache
# Processing Record 28 of Set 13 | kosh-agach
# Processing Record 29 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 13 | lasa
# Processing Record 31 of Set 13 | sangar
# Processing Record 32 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 33 of Set 13 | florencia
# Processing Record 34 of Set 13 | tabuk
# Processing Record 35 of Set 13 | liling
# Processing Record 36 of Set 13 | entre rios
# Processing Record 37 of Set 13 | payo
# Processing Record 38 of Set 13 | biak
# Processing Record 39 of Set 13 | along
# Processing Record 40 of Set 13 | bukama
# Processing Record 41 of Set 13 | chernyshevskiy
# Processing Record 42 of Set 13 | mount isa
# Processing Record 43 of Set 13 | bourail
# Processing Record 44 of Set 13 | bhongir
# Processing Record 45 of Set 13 | la paz centro
# Processing Record 46 of Set 13 | oranjestad
# Processing Record 47 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 48 of Set 13 | borogontsy
# Processing Record 49 of Set 13 | sinnamary
# Processing Record 50 of Set 13 | cap malheureux
# Processing Record 1 of Set 14 | obera
# Processing Record 2 of Set 14 | harnosand
# Processing Record 3 of Set 14 | enzan
# Processing Record 4 of Set 14 | silver city
# Processing Record 5 of Set 14 | awjilah
# Processing Record 6 of Set 14 | antofagasta
# Processing Record 7 of Set 14 | vardo
# Processing Record 8 of Set 14 | solnechnyy
# Processing Record 9 of Set 14 | ganzhou
# Processing Record 10 of Set 14 | singaraja
# Processing Record 11 of Set 14 | bondo
# Processing Record 12 of Set 14 | batagay
# Processing Record 13 of Set 14 | moree
# Processing Record 14 of Set 14 | watertown
# Processing Record 15 of Set 14 | juneau
# Processing Record 16 of Set 14 | port hawkesbury
# Processing Record 17 of Set 14 | siniscola
# Processing Record 18 of Set 14 | tual
# Processing Record 19 of Set 14 | oranjemund
# Processing Record 20 of Set 14 | la ronge
# Processing Record 21 of Set 14 | sydney mines
# Processing Record 22 of Set 14 | muisne
# Processing Record 23 of Set 14 | shuangcheng
# Processing Record 24 of Set 14 | port macquarie
# Processing Record 25 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 14 | sao lourenco do sul
# Processing Record 27 of Set 14 | ratnagiri
# Processing Record 28 of Set 14 | bud
# Processing Record 29 of Set 14 | oeiras do para
# Processing Record 30 of Set 14 | sumbe
# Processing Record 31 of Set 14 | majene
# Processing Record 32 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 14 | rio de janeiro
# Processing Record 34 of Set 14 | yambio
# Processing Record 35 of Set 14 | voskevan
# Processing Record 36 of Set 14 | nicolas bravo
# Processing Record 37 of Set 14 | broken hill
# Processing Record 38 of Set 14 | balkanabat
# Processing Record 39 of Set 14 | ust-nera
# Processing Record 40 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 41 of Set 14 | acapulco
# Processing Record 42 of Set 14 | vrangel
# Processing Record 43 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 14 | nantucket
# Processing Record 45 of Set 14 | qaqortoq
# Processing Record 46 of Set 14 | salinas
# Processing Record 47 of Set 14 | guajara-mirim
# City not found. Skipping...
# Processing Record 48 of Set 14 | santa maria da vitoria
# Processing Record 49 of Set 14 | henties bay
# Processing Record 50 of Set 14 | sur
# Processing Record 1 of Set 15 | jega
# Processing Record 2 of Set 15 | menongue
# Processing Record 3 of Set 15 | tongchuan
# Processing Record 4 of Set 15 | koulikoro
# Processing Record 5 of Set 15 | griffith
# Processing Record 6 of Set 15 | luchenza
# Processing Record 7 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 15 | baruun-urt
# Processing Record 9 of Set 15 | poyarkovo
# Processing Record 10 of Set 15 | antsohihy
# Processing Record 11 of Set 15 | huilong
# Processing Record 12 of Set 15 | ewa beach
# Processing Record 13 of Set 15 | sydney
# Processing Record 14 of Set 15 | utrecht
# Processing Record 15 of Set 15 | timra
# Processing Record 16 of Set 15 | hurghada
# Processing Record 17 of Set 15 | giddalur
# Processing Record 18 of Set 15 | harrisburg
# Processing Record 19 of Set 15 | krasnoarmeysk
# Processing Record 20 of Set 15 | phangnga
# Processing Record 21 of Set 15 | show low
# Processing Record 22 of Set 15 | inhambane
# Processing Record 23 of Set 15 | karpathos
# Processing Record 24 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 15 | salamiyah
# Processing Record 26 of Set 15 | kangaatsiaq
# Processing Record 27 of Set 15 | hidalgotitlan
# Processing Record 28 of Set 15 | arona
# Processing Record 29 of Set 15 | matias olimpio
# Processing Record 30 of Set 15 | san carlos de bariloche
# Processing Record 31 of Set 15 | kimparana
# Processing Record 32 of Set 15 | klerksdorp
# Processing Record 33 of Set 15 | ilo
# Processing Record 34 of Set 15 | lorengau
# Processing Record 35 of Set 15 | kabare
# Processing Record 36 of Set 15 | skjervoy
# Processing Record 37 of Set 15 | vestmanna
# Processing Record 38 of Set 15 | ureki
# Processing Record 39 of Set 15 | great yarmouth
# Processing Record 40 of Set 15 | macroom
# Processing Record 41 of Set 15 | san cristobal
# Processing Record 42 of Set 15 | opuwo
# Processing Record 43 of Set 15 | guerrero
# Processing Record 44 of Set 15 | madridejos
# Processing Record 45 of Set 15 | romanovo
# Processing Record 46 of Set 15 | yebaishou
# Processing Record 47 of Set 15 | swift current
# Processing Record 48 of Set 15 | hofn
# Processing Record 49 of Set 15 | atkinson
# Processing Record 50 of Set 15 | harper
# Processing Record 1 of Set 16 | iztapa
# Processing Record 2 of Set 16 | vostok
# Processing Record 3 of Set 16 | concepcion
# Processing Record 4 of Set 16 | timmins
# Processing Record 5 of Set 16 | lazaro cardenas
# Processing Record 6 of Set 16 | khonsa
# Processing Record 7 of Set 16 | haimen
# Processing Record 8 of Set 16 | conakry
# Processing Record 9 of Set 16 | shediac
# Processing Record 10 of Set 16 | arroyo
# Processing Record 11 of Set 16 | ilheus
# Processing Record 12 of Set 16 | monte di procida
# Processing Record 13 of Set 16 | belyy yar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame
#city_data_df = pd.DataFRame(city_data)
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kapaa      US  22.0752 -159.3190     73.72        92         100
# 1     Busselton      AU -33.6500  115.3333     58.84        67          83
# 2  Bahia Blanca      AR -38.7196  -62.2724     58.37        32           0
# 3      Hermanus      ZA -34.4187   19.2345     58.80        73           8
# 4        Torbay      CA  47.6666  -52.7314     39.27        94         100
# 5         Nesna      NO  66.1967   13.0213     43.66        86         100
# 6   Port Alfred      ZA -33.5906   26.8910     60.19        82          55
# 7        Atuona      PF  -9.8000 -139.0333     78.85        71          96
# 8          Uige      AO  -7.6087   15.0613     75.72        78          81
# 9       Kumluca      TR  36.3703   30.2869     69.87        61          27
#
#    Wind Speed Current Description
# 0       13.80     overcast clouds
# 1       12.08       broken clouds
# 2       10.33           clear sky
# 3        4.09           clear sky
# 4       10.00     overcast clouds
# 5       22.77     overcast clouds
# 6        1.01       broken clouds
# 7       20.71     overcast clouds
# 8        2.86       broken clouds
# 9        4.47    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "C:\\Users\\qatester\\Documents\\Class Folder\\World_Weather_Analysis\\Weather_Database\\WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
